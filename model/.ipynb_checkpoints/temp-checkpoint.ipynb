# %% [markdown]
# <!-- ```{list-table} Transition Characters
# :class: tight-table-style
# :header-rows: 1
# :name: tbl:transition-characters
#
# * - component
#   - $\Delta m$
#   - name
#   - polarization
#   - direction
# * - |$\hat{d}_0$
#   - $0$
#   - $\pi$
#   - linear
#   - parallel to $z$
# * - $\hat{d}_{+1}$
#   - $+1$
#   - $\sigma^{+}$
#   - circular
#   - in $xy$ plane
# * - $\hat{d}_{-1}$
#   - $-1$
#   - $\sigma^{-}$
#   - circular
#   - in $xy$ plane
# ``` -->
