# %%
import matplotlib.pyplot as plt
import numpy as np
from qutip import *

# %%
# %run trimer-case2-qme.ipynb
# Out:
# ** Check: energy eigenvalue **
#  -1.50000   -1.50000
#  -0.52327   -0.52327
#  -0.48837   -0.48837
#  -0.48837   -0.48837
#   0.47673    0.47673
#   0.51163    0.51163
#   0.51163    0.51163
#   1.50000    1.50000
#       Channel 1:     1.023 (0.023),     1.000 (0.000),      0.977 (0.024)
#   Channel 2 & 3:     0.988 (0.012),     1.000 (0.000),      1.012 (0.012)
# ** occupation probability of Dicke state **
#  n     rho_ss      Gibbs
#  0    0.019452   0.019451
#  1    0.052877   0.054118
#  2    0.052877   0.052261
#  3    0.052877   0.052261
#  4    0.143735   0.147107
#  5    0.143735   0.142061
#  6    0.143735   0.142061
#  7    0.390712   0.390680
