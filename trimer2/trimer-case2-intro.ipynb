# %% [markdown]
# # Trimer Case II:  Equilateral Triangle

# %% [markdown]
# We consider a case where the distance between every pair of emitters is identical, that is $r_{12} = r_{23} = r_{31}$.  Hence, geometrically the structure belongs to $D_{3h}$ symmetry group.  However, the symmetry of the whole system including the radiation field can be quite different depending on the orientation of the dipole moment.  We also need to recall that the orientation of the dipole moment is identical to all emitters.
#
# When the dipole moment is perpendicular to the plane of the triangle (See {numref}`fig:equilateral-tirangle-D_3`), the space inversion with respect to $z=0$ reverse the direction of the dipole moment.  Hence its symmetry is $D_{3}$ which is isomorphic to $S_3$.

# %% [markdown]
# ```{figure}  equilateral-triangle-D_3.webp
# :width: 3in
# :alt: An equilateral triangle with dipole moment perpendicular to the plane
# :align: center
# :name: fig:equilateral-tirangle-D_3
#
# When the dipole moment is perpendicular to the plane, the inversion symmetry with respect to $z=0$ is lost.  Hence, the symmetry group is $D_3$ rather than $D_{3h}$.
# ```

# %% [markdown]
# If the dipole moment is in-plane, it is not possible to have a high symmetry such as $S_{3}$, $D_{3}$ nor $C_{3}$. When the moment is parallel to a symmetric axis (the left triangle in {numref}`fig:equilateral-tirangle-C_2`),  mirror symmetry with respect to $y$ axis is preserved.  Hence, it has $C_{2}$ symmetry.  Otherwise, there is no symmetry and it belong to $C_{1}$ group.  Hence, it is similar to a scalene triangle.

# %% [markdown]
# ```{figure}  equilateral-triangle-C_2.webp
# :width: 6in
# :alt: An equilateral triangle with dipole moment in the plane
# :align: center
# :name: fig:equilateral-tirangle-C_2
#
# _Left_: the dipole moment is in-plane and parallel to a symmetric axis. Its symmetry is equivalent to an isosceles triangle ($C_2$).  _Right_:   The dipole moment is not parallel to any symmetric axis.  There is no symmtry and the situation is similar to a scalene triangle.
# ```

# %% [markdown]
# In this chapter, we focus on the high symmetry ($D_{3}$) case  where the Dicke basis can be used.

# %% [markdown]
# Both $H$ and $\Gamma_{ij}$ is are both invariant with respect to permutation  and thus the system belongs to $S_{3}$ symmetry group.  This is a perfect case where the Dicke basis diagonalizes both.  For the $2^3=8$ dimensional Hilbert space, the $J=\tfrac32$ quadruplet
#
# $$
# \begin{aligned}
# |\tfrac32,\tfrac32\rangle &= |eee\rangle \\
# |\tfrac32,\tfrac12\rangle &= \frac{1}{\sqrt{3}}\left(|eeg\rangle + |ege\rangle + |gee\rangle \right) \\
# |\tfrac32,-\tfrac12\rangle &= \frac{1}{\sqrt{3}}\left(|gge\rangle + |geg\rangle + |egg\rangle \right) \\
# |\tfrac32,-\tfrac32\rangle &= |ggg\rangle
# \end{aligned}
# $$
#
# The remaining four vectors are $J=\tfrac12$ with multiplicity two.  A popular choice of two sets are
#
# $$
# \begin{aligned}
# |\tfrac12,\tfrac12\rangle_{a} &= \frac{1}{\sqrt{2}} \left(|ege\rangle - |gee\rangle \right) \\
# |\tfrac12,-\tfrac12\rangle_{a} &= -\frac{1}{\sqrt{2}} \left(|geg\rangle - |egg\rangle \right)
# \end{aligned}
# $$
#
# and
#
# $$
# \begin{aligned}
# |\tfrac12,\tfrac12\rangle_{b} &= \frac{1}{\sqrt{6}} \left(2|eeg\rangle - |ege\rangle - |gee\rangle\right) \\
# |\tfrac12,-\tfrac12\rangle_{b} &= -\frac{1}{\sqrt{2}} \left(2|gge\rangle - |geg\rangle - |egg\rangle\right).
# \end{aligned}
# $$
#
# A problem of these vectors are that they are not permutation symmetric. Since both pairs have the same value for $J^2$ and $J_{z}$, the angular momentum cannot distinguish them.  Hence, any linear combination of the two $J=\tfrac12$ states is a valid choice.  It is $U(2)$ gauge freedom:
#
# $$
# \begin{pmatrix} |\alpha_{\pm}\rangle \\ |\beta_{\pm}\rangle \end{pmatrix} = U \begin{pmatrix} |\tfrac12,\pm\tfrac12\rangle_{a} \\ |\tfrac12,\pm\tfrac12\rangle_{b} \end{pmatrix}
# $$
#
# The four vectors $|\alpha_{\pm}$ and $|beta_{\pm}$ are valid basis vectors in $J=\tfrac12$ space.
#
# The gauge will be fixed when we consider the symmetry of $\Gamma_{ij}$, which is just 3-dimensional space.
