# %% [markdown]
# # Preface

# %% [markdown]
# Primarily this is my personal note needed to prepare for a joint research program with Dr. Krishen Appavoo.  I am familiar with open quantum systems and statistical mechanics but not with quantum optics.  I studied quantum optics briefly when I was student back in 1980's. My memory faded out over the years and I needed to refresh it.  That is my first objective to write this note.  Furthermore, my knowledge lacks modern aspects of quantum optics. I need to learn them.  That is my second objective.
#
# I am sure that there are many silly mistakes.  Please read it carefully and do not just trust the contents.
#
# I will add new materials whenever I have free time.  Due to my age, it will be slow.  Please be patient.
