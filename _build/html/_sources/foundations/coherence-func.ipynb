# %% [markdown]
# (ch:coherence-func)=
# # Coherence functions

# %% [markdown]
# In the theory of optics, several spatiotemporal correlations of radiation fields are used to quantify coherence of the radiation.  Here, we introduce the first- and second- order coherence functions relevant to the topics discussed in the present lecture note.
