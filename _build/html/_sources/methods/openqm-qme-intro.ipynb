# %% [markdown]
# (ch:openqm-qme)=
# # Quantum master equations

# %% [markdown]
# As we discussed in {numref}`ch:coherence`, coherence is not a property of the system.  It is a property of a reduce density matrix expressed in a certain basis set.   Rigorously speaking, we need to find the density operator of the whole system including at least the emitters and the radiation field and then take partial trace over the radiation field. However, it is very difficult to do so.  Under a weak coupling limit, there is a direct method to compute the reduce density matrix without computing the state of the whole system. The method is known as open quantum system approach. In many practical cases, the interaction between the radiation field and the emitters is weak and such approach works quite well.  Using the reduced density matrix, we can compute ensemble average like regular quantum mechanics.
#
# for a closed system, we solve the Schrodinger equation $i \frac{d}{dt} |\psi\rangle = H |\psi\rangle$ or  the Liouville-von Neumann equation $i \frac{d}{dt}\rho = [H , \rho]$.  In the open quantum system approach, we solve a quantum master equation (also known as Lindblad equation){cite:p}`Breuer2002`, $\frac{d}{dt}\rho = \mathcal{L} \rho$ which is introduced below.
#
# There are many excellent textbooks.  The following list includes only a few of them.
#
# **Books**
# * Carmichael (1993): _An Open Systems Approach to Quantum Optics_  CH. 1-6 {cite:p}`Carmichael1993`
# * Gardiner and Zoller (2000): _Quantum Noise_ CH. 5-6 {cite:p}`Gardiner2000`
# * Breuer and Petruccione (2002): _The Theory of Open Quantum Systems_ CH. 3-4 {cite:p}`Breuer2002`
# * Carmichamel (2002): _Statistical Methods in Quantum Optics 1_ CH. 1  {cite:p}`Carmichael1993`
# * Lambropoulos (2007): _Fundamentals of Quantum Optics and Quantum Information_ CH. 4 {cite:p}`Lambropoulos2007`
# * Meystre (2007): _Elements of Quantum Optics_ CH. 15 {cite:p}`Meystre2007`
# * Wiseman and Milburn (2010): _Quantum measurement and control_ CH.3 {cite:p}`Wiseman2010`
# * Rice (2025): _An Introduction to Quantum Optics_ CH. 10 {cite:p}`Rice2025`
